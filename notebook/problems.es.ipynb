# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
n_experimentos = 1000
contador = 0

# %%
import numpy as np

def experiment_proba(n_experimentos):
    contador = 0

    for i in range(n_experimentos):

        dado1 = np.random.randint(1,7) 
        dado2 = np.random.randint(1,7)
        suma_dados = dado1 + dado2

        if (suma_dados > 7 ) or ((suma_dados % 2) == 0):
            contador += 1

    prop = contador / n_experimentos
    return prop

experiment_proba(1000)
# Out:
# 0.656

# %%
print(f"Probabilidad de que la suma sea  un numero par o mayor a 7 e : {experiment_proba(1000)}")
# Out:
# Probabilidad de que la suma sea  un numero par o mayor a 7 e : 0.662

# %%
experiment_proba(4)
# Out:
# 0.75

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"


            
colores_por_indice = ["White"] * 10 + ["Red"] * 20 + ["Green"] * 30
colores_array = np.array(colores_por_indice)


numero_exp = 1000
con_3blancas_2rojas = 0
con_mismo_color = 0

for i in range(numero_exp):
    
    extraccion = np.random.choice(colores_array, size=5, replace=True)

    blancas = np.sum(extraccion == "White")
    rojas = np.sum(extraccion == "Red")
    verdes = np.sum(extraccion == "Green")

    if blancas == 3 and rojas == 2:
        con_3blancas_2rojas += 1


    if (blancas == 5) or (rojas == 5) or (verdes == 5):
        con_mismo_color += 1

    prob_1 = con_3blancas_2rojas / numero_exp
    prob_2 = con_mismo_color / numero_exp



print(f"Probabilidad de 3 blancas y 2 rojas: {prob_1}")
print(f"Probabilidad de todas del mismo color: {prob_2}")
# Out:
# Probabilidad de 3 blancas y 2 rojas: 0.008
# Probabilidad de todas del mismo color: 0.034

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"


numero_extracciones = 1000 
con_3blancas_2rojas = 0
extraccion_match = None

for i in range(numero_extracciones):
   
    extraccion = np.random.choice(colores_array, size=5, replace=True)
    
  
    blancas = np.sum(extraccion == "White")
    rojas = np.sum(extraccion == "Red")

   
    if blancas == 3 and rojas == 2:
        con_3blancas_2rojas += 1
        extraccion_match = extraccion


prob_3blancas_2rojas = con_3blancas_2rojas / numero_extracciones


print(f"Extracción que cumple con 3 blancas y 2 rojas: {extraccion_match}")
print(f"Probabilidad de obtener 3 blancas y 2 rojas: {prob_3blancas_2rojas}")
# Out:
# Extracción que cumple con 3 blancas y 2 rojas: ['White' 'White' 'White' 'Red' 'Red']
# Probabilidad de obtener 3 blancas y 2 rojas: 0.005
